# %%
print('hello world') # my code
# my code
# Out:
# hello world

# %% [markdown]
# # Markdown
# ## Markdown
# ### Markdown
# #### Markdown
# **python** is really good
# - python
#   - pandas
#   - numpy
# - java
#
# 수식 예: $y = ax^2 + bx + c$
#
# $\int_{0}^{1} x(t) dt$
#
# $\frac{a}{b+c}$
#
# ```python
# print('hello world')
# a = 100
# b = 200
# ```
#
# [정보통신공학부](http://inform.cbnu.ac.kr)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.21.0'

# %% [markdown]
# - tensorflow import안되는 학생은 jupyter notebook 에서 아래와 같이 실행해볼 것
# - jupyter notebook에 tensorflow를 직접 설치하는 명령어임
# ```python
# import sys
# !{sys.executable} -m pip install tensorflow
# ```

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.12.0'

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('test2.png', 1)
cv2.imshow('HSKANG', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Python (변수)

# %%
a = 10
b = 11.4

# %%
print(a, b)
print(a, 100, 200, b)
print(a, 100, 200, b, sep=', ', end='...\n')
# Out:
# 10 11.4
# 10 100 200 11.4
# 10, 100, 200, 11.4...

# %%
a, b # tuple
# Out:
# (10, 11.4)

# %%
a
b
# Out:
# 11.4

# %%
c = None

# %%
print(a, b, c)
# Out:
# 10 11.4 None

# %%
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'float'> <class 'NoneType'>

# %%
a = 'hello_world'

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(a, a[0], a[3], a[-1], a[10], a[-3])
# Out:
# hello_world h l d d r
