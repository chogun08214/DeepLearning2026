# %%
import numpy as np

# %%
arr = np.array([[1., 2, 3], [1, 2, 3]])
print(arr.dtype)
# Out:
# float64

# %%
arr1 = arr.astype(np.int8)
print(arr1, arr1.dtype)
# Out:
# [[1 2 3]
#  [1 2 3]] int8

# %%
arr = np.array([[1., 2, 3], [1, 2, 3]], dtype = 'int32')
print(arr.dtype)
# Out:
# int32

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
arr = np.array([[1., 2, 3], [1, 2, 3]], dtype = 'int32')
print(arr.shape)
# Out:
# (2, 3)

# %%
arr1 = arr.reshape(1, 6)
print(arr1, arr1.shape)
print(arr, arr.shape)
# Out:
# [[1 2 3 1 2 3]] (1, 6)
# [[1 2 3]
#  [1 2 3]] (2, 3)

# %%
arr1 = arr.reshape(1, -1)
print(arr1, arr1.shape)
print(arr, arr.shape)
# Out:
# [[1 2 3 1 2 3]] (1, 6)
# [[1 2 3]
#  [1 2 3]] (2, 3)

# %%
arr1 = arr.reshape(-1, 1)
print(arr1, arr1.shape)
print(arr, arr.shape)
# Out:
# [[1]
#  [2]
#  [3]
#  [1]
#  [2]
#  [3]] (6, 1)
# [[1 2 3]
#  [1 2 3]] (2, 3)

# %%
arr = np.random.randn(3, 4)
print(arr, arr.shape)
# Out:
# [[-0.1448882   1.29570949 -1.12722047 -0.79482724]
#  [-0.67542439 -1.84514449 -2.02845815 -0.62918755]
#  [-1.95733527  0.23132408 -0.12206499  1.0045049 ]] (3, 4)

# %%
arr1 = arr.reshape(4, 3)
print(arr1, arr1.shape)
# Out:
# [[-0.1448882   1.29570949 -1.12722047]
#  [-0.79482724 -0.67542439 -1.84514449]
#  [-2.02845815 -0.62918755 -1.95733527]
#  [ 0.23132408 -0.12206499  1.0045049 ]] (4, 3)

# %%
arr2 = arr.reshape(-1, 2, 1)
print(arr2, arr2.shape)
# Out:
# [[[-0.1448882 ]
#   [ 1.29570949]]
#
#  [[-1.12722047]
#   [-0.79482724]]
#
#  [[-0.67542439]
#   [-1.84514449]]
#
#  [[-2.02845815]
#   [-0.62918755]]
#
#  [[-1.95733527]
#   [ 0.23132408]]
#
#  [[-0.12206499]
#   [ 1.0045049 ]]] (6, 2, 1)

# %%
arr3 = arr.reshape(-1)
print(arr3, arr3.shape)
# Out:
# [-0.1448882   1.29570949 -1.12722047 -0.79482724 -0.67542439 -1.84514449
#  -2.02845815 -0.62918755 -1.95733527  0.23132408 -0.12206499  1.0045049 ] (12,)

# %%
arr = np.random.randn(3, 4)
print(arr, arr.shape)
# Out:
# [[ 2.06654234  0.76543068 -0.46202188 -0.63086546]
#  [ 1.0219415   0.10055074  0.72339111 -1.27283406]
#  [ 0.33561273  1.04119546 -0.48852954 -0.22342274]] (3, 4)

# %%
arr3 = arr.reshape(1, 3, 4)
print(arr3, arr3.shape)
# Out:
# [[[ 2.06654234  0.76543068 -0.46202188 -0.63086546]
#   [ 1.0219415   0.10055074  0.72339111 -1.27283406]
#   [ 0.33561273  1.04119546 -0.48852954 -0.22342274]]] (1, 3, 4)

# %%
arr4 = arr.reshape(1, 1, 3, 4)
print(arr4, arr4.shape)
# Out:
# [[[[ 2.06654234  0.76543068 -0.46202188 -0.63086546]
#    [ 1.0219415   0.10055074  0.72339111 -1.27283406]
#    [ 0.33561273  1.04119546 -0.48852954 -0.22342274]]]] (1, 1, 3, 4)

# %%
arr5 = np.expand_dims(arr4, 3)
print(arr5, arr5.shape)
# Out:
# [[[[[ 2.06654234  0.76543068 -0.46202188 -0.63086546]]
#
#    [[ 1.0219415   0.10055074  0.72339111 -1.27283406]]
#
#    [[ 0.33561273  1.04119546 -0.48852954 -0.22342274]]]]] (1, 1, 3, 1, 4)

# %% [markdown]
# ## Matplotlib

# %%
data = np.random.randn(50)
print(data)
# Out:
# [ 0.91705811  0.81505391  1.91859579 -0.555401    0.86844933  0.84634474
#  -0.06479111  1.53124716 -0.36404093 -0.07548366  2.05676827  0.71322915
#   0.26045384 -1.21522943 -1.34561047 -1.89597921  0.17836588 -1.05304221
#   0.25248758 -2.31953756 -0.26296273 -1.34714398 -0.42675885 -0.27393059
#   0.4506981   1.41971545  1.23149619  1.24271307  0.03309368 -1.39164584
#  -0.68010782 -0.69306269  1.05062553  2.59028441 -0.73332522  0.09590698
#  -0.84278351  2.82055184 -0.61362924  0.8799598   0.46080098  0.09545628
#  -1.0137174   0.01926799  0.18387156 -0.13067925 -0.86240199  0.21606007
#  -0.86706563 -0.76542501]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)
plt.show()

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(100) 
#scat_data, hist_data

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(hist_data, 'r+')
plt.subplot(2, 2, 2)
plt.hist(hist_data, bins=20)
plt.subplot(2, 2, 3)
plt.scatter(scat_data, hist_data)
plt.show()

# %%
hist_data = np.random.randn(100000)
plt.hist(hist_data, bins = 100)
plt.show()

# %%
data = np.random.randn(100)
plt.title('random')
plt.xlabel('index')
plt.ylabel('height')
plt.plot(data, 'rx')
plt.show()

# %%
plt.title('random')
plt.xlabel('index')
plt.ylabel('height')
plt.plot(np.random.randn(100).cumsum(), 'r^', label = 'one')
plt.plot(np.random.randn(100).cumsum(), 'g.', label = 'two')
plt.plot(np.random.randn(100).cumsum(), 'b--', label = 'three')
plt.legend()
plt.savefig('graph.png')
plt.show()

# %%
from PIL import Image

# %%
#path = 'graph.png'
path = 'wallpaper-696758.jpg'
img_pil = Image.open(path)
img_np = np.array(img_pil)

# %%
img_np.shape
# Out:
# (576, 1024, 3)

# %%
np.min(img_np), np.max(img_np)
# Out:
# (np.uint8(0), np.uint8(255))

# %%
plt.imshow(img_np)
plt.show()

# %%
plt.hist(img_np.reshape(-1), bins=256)
plt.show()

# %%
path = 'wallpaper-696758.jpg'
img_pil = Image.open(path).convert('L')
img_np = np.array(img_pil)

# %%
img_np.shape
# Out:
# (576, 1024)

# %%
plt.imshow(img_np, 'gray')
plt.show()

# %%
plt.imshow(img_np, 'jet')
plt.colorbar()
plt.show()

# %%
import cv2

# %%
path = 'wallpaper-696758.jpg'
img_bgr = cv2.imread(path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_resize = cv2.resize(img_rgb, (500, 500))
img_bgr.shape, img_rgb.shape, img_resize.shape
# Out:
# ((576, 1024, 3), (576, 1024, 3), (500, 500, 3))

# %%
plt.imshow(img_resize)
plt.show()
